# %%
import Practica03 as p3

p3.main()
# Out:
# All tests passed!
# All tests passed!
# Matriz de confusion ([[TN, FP],[FN, TP]]):
# [[5000    0]
#  [   0    0]]
# F1Score=0, TN=5000, FP=0, FN=0, TP=0
