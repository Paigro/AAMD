# %%
import Practica03 as p3

p3.main()
# Out:
# All tests passed!
# All tests passed!
# Matriz de confusion ([[TN, FP],[FN, TP]]):
# [[4491    9]
#  [   4  496]]
# F1Score=0.9870646766169153, TN=4491, FP=9, FN=4, TP=496
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import Practica03 as p3
#       3 p3.main()
#
# File c:\Users\invitado\Documents\GitHub\AAMD\Practica3\Practica03.py:39
#      35     print(f"F1Score={f1}, TN={tn}, FP={fp}, FN={fn}, TP={tp}")
#      37     displayData(x)
# ---> 39 main()
#
# File c:\Users\invitado\Documents\GitHub\AAMD\Practica3\Practica03.py:37, in main()
#      34 print(cm)
#      35 print(f"F1Score={f1}, TN={tn}, FP={fp}, FN={fn}, TP={tp}")
# ---> 37 displayData(x)
#
# File c:\Users\invitado\Documents\GitHub\AAMD\Practica3\utils.py:36, in displayData(X, example_width, figsize)
#      33 ax_array = [ax_array] if m == 1 else ax_array.ravel()
# ...
