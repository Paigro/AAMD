# %% [markdown]
# ### Ejercicio 1, 2 y 3.
# Hemos implementado una funcion en Utils que selecciona los csv que contienen la palabra "win" y los mueve a una carpeta dentro de data, ademas junta todos los csv de manera recursiva de la carpeta data (por si queremos añadir datos externos).
#
# Hemos implementado otra funcion en Utils que genera un grafico pca de 2 componentes dividiendo por colores las clases
#
# Usando un array de strings con el nombre de las columnas que queremos usar, se criban los datos

# %%
from Utils import display_pca_classes
from Practica5 import read_files

# Rutas de los archivos
org_path = "./../"
dest_path = "./data/destination_csvs"
# Mover los archivos CSV y obtener los datos normalizados
X_norm, y_onehot, y, mu, sigma = read_files(file_path=org_path, dest_path=dest_path)
# Visualizar los datos normalizados usando PCA
display_pca_classes(X_norm, y, name="pca.png")
# Out:
# Filas antes: 36212, después: 35966

# %% [markdown]
# ### Ejercicio 4.
# Para este ejercicio hemos implementado todos los tipos de modelos llegando a unas precisiones similares:

# %%
from sklearn.model_selection import train_test_split

# Dividir en conjunto de entrenamiento y prueba (80% - 20%)
X_train_ohe, X_test_ohe, y_train_ohe, y_test_ohe = train_test_split(X_norm, y_onehot, train_size = 0.8, random_state = 1234)
X_train_other, X_test_other, y_train_other, y_test_other = train_test_split(X_norm, y, train_size = 0.8, random_state = 1234)

# %% [markdown]
# > MLP SKLearn
# - Precisión (Accuracy) en ENTRENAMIENTO: 83.82%
# - Precisión (Accuracy) en TEST: 79.04%

# %%
from Practica5 import MLP_sklearn

# Entrenamiento y evaluación del modelo MLP de sklearn
model_mlp_sklearn = MLP_sklearn(X_train_ohe, y_train_ohe, X_test_ohe, y_test_ohe)
# Out:
# Entrenando modelo MLP SKLearn...
#
# ...
# Evaluando MLP SKLearn
# ...
# Precisión (Accuracy) en ENTRENAMIENTO: 83.82%
# Precisión (Accuracy) en TEST: 79.04%
# ...

# %% [markdown]
# > MLP Custom
# - Precisión (Accuracy) en ENTRENAMIENTO: 33.36%
# - Precisión (Accuracy) en TEST: 32.23%

# %%
from Practica5 import MLP_custom

# Entrenamiento y evaluación del modelo MLP personalizado
model_mlp_custom = MLP_custom(X_train_ohe, y_train_ohe, X_test_ohe, y_test_ohe)
# Out:
# Entrenando modelo MLP Custom...
# Iteration      1: Cost   3.3768
# Iteration    501: Cost   1.7464
# Iteration   1001: Cost   1.4829
# Iteration   1501: Cost   1.3552
#
# ...
# Evaluando MLP Custom
# ...
# Precisión (Accuracy) en ENTRENAMIENTO: 75.20%
# Precisión (Accuracy) en TEST: 74.49%
# ...

# %% [markdown]
# > KNN
# - Precisión (Accuracy) en ENTRENAMIENTO: 82.09%
# - Precisión (Accuracy) en TEST: 78.76%

# %%
from Practica5 import KNN

# Entrenamiento y evaluación del modelo KNN
model_knn = KNN(X_train_other, y_train_other, X_test_other, y_test_other)
# Out:
# Entrenando modelo KNN...
#
# ...
# Evaluando KNN
# ...
# Precisión (Accuracy) en ENTRENAMIENTO: 82.09%
# Precisión (Accuracy) en TEST: 78.76%
# ...

# %% [markdown]
# > Decission Tree
# - Precisión (Accuracy) en ENTRENAMIENTO: 98.91%
# - Precisión (Accuracy) en TEST: 84.46%

# %%
from Practica5 import decission_tree

# Entrenamiento y evaluación del modelo Decision Tree
model_dt = decission_tree(X_train_other, y_train_other, X_test_other, y_test_other)
# Out:
# Entrenando modelo Decission Tree...
#
# ...
# Evaluando Decission_Tree
# ...
# Precisión (Accuracy) en ENTRENAMIENTO: 98.91%
# Precisión (Accuracy) en TEST: 84.46%
# ...

# %% [markdown]
# > Random Forest
# - Precisión (Accuracy) en ENTRENAMIENTO: 98.91%
# - Precisión (Accuracy) en TEST: 87.95%

# %%
from Practica5 import random_forest

# Entrenamiento y evaluación del modelo Random Forest
model_rf = random_forest(X_train_other, y_train_other, X_test_other, y_test_other)
# Out:
# Entrenando modelo Random Forest...
#
# ...
# Evaluando random_forest
# ...
# Precisión (Accuracy) en ENTRENAMIENTO: 98.91%
# Precisión (Accuracy) en TEST: 87.95%
# ...

# %% [markdown]
# ##### Conclusión:
# Vistos los resultados llegamos a la conclusion que el modelo mas preciso es el Random Forest, y el menos, nuestro propio MLP

# %% [markdown]
# ### Ejercicio 5.
# Para importar nuestro modelo en Unity primero hemos tenido que exportarlo, para ello usamos la funcion propia "export_model" definida en Practica5.py

# %%
from Practica5 import export_model

export_model(model_mlp_sklearn, X_train_ohe, mu=mu, sigma=sigma)
# Out:
# Capa  coefficient
# procesando  coefficient
# ['15', '100']
# coefficient
# ...
